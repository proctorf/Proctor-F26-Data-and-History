# %% [markdown]
# # [Unit Number] — [Unit Topic]

# %% [markdown]
# **Before you start:**
#
# - Give each concrete step in the process its own cell. If you cannot describe what a cell does in a short phrase ("load the text file," "strip punctuation," "count word frequency"), it is probably two steps — split it into two cells.
# - Add a Markdown cell above each code cell explaining what you're about to do and *why* — write the explanation **before** you write the code. This forces you to say what you expect to happen before you find out what actually happens. Here is a <a href="Markdown-Cheatsheet.html" target="_blank">**CHEAT SHEET**</a> for Markdown codes. Here is an even more <a href="https://www.markdownguide.org/cheat-sheet/" target="_blank">**COMPLETE CHEAT SHEET**</a>
# - Use `#` comments inside code cells for line-level notes (why a line is written a certain way, what a tricky argument does, reminders to yourself. **Remember the 6-month rule** - You want to be able to know what is going on in your code if you were to open it 6 months from now.
# - Log anything that breaks in the **Failure Log** at the bottom of this notebook — even if you never fixed it. Note the error message and what you tried.
#
# Rename this file using the format `Unnamed-##-UnitTopic-Notebook.ipynb` before you begin (e.g. `Proctor-02-Python-Basics-Notebook.ipynb`).
# You can accomplish this either by making a copy of the file in your Finder or File Explorer and renaming it there. Or, you can do it after you open Jupyter Notebooks using the folder navigation there. Be warned: Notebooks to not like a double click!

# %% [markdown]
# ## Imports

# %%
import re
from collections import Counter

# %% [markdown]
# ## Imports
#
# Run this cell once, at the start of your session. Add every `import` statement for this notebook here — you shouldn't need to re-run this as you work through the rest of the notebook.

# %% [markdown]
# # Define my Functions

# %%
def split_into_words(any_chunk_of_text):
    lowercase_text = any_chunk_of_text.lower()
    split_words = re.split("\W+", lowercase_text)
    return split_words

# %% [markdown]
# ---
#
# ## Your Work
#
# Build your notebook below, one concrete step at a time. For each step:
#
# 1. Add a Markdown cell describing what you're about to do and why.
# 2. Add a code cell that does it.
# 3. Run it, check the output, and add `#` comments for anything worth remembering about that line.
#
# Repeat for as many steps as the chapter/unit walks through — including if it introduces a new dataset, a new function, or a new example partway through. Don't feel like you need to force everything into a single sequence if the material doesn't.

# %% [markdown]
# ### Step 1: [describe this step]

# %% [markdown]
# ---
#
# ## Failure Log
#
# Note anything that broke, any error message you didn't understand, and what you tried — even if it didn't work. You don't need to have fixed it.
#
# -
# -
# -
